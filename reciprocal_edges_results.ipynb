# %%
import pandas as pd
# Complex_Network_Analysis, Solar_Cells, Gravitational_Waves, Magnetic_Thin_Films, LHC
TOPIC_NAME = "Solar_Cells"

# %%
df_edges = pd.read_csv(f"data/reciprocal_edges_by_year_{TOPIC_NAME}_2005_2025.csv")
#first column is a tupe of (year, (institution1, institution2)), change it to three columns: year, institution1, institution2
df_edges[["year", "institution1", "institution2"]] = df_edges["Unnamed: 0"].str.extract(r"\((\d+), \('(.+)', '(.+)'\)\)")
df_edges = df_edges.drop(columns=["Unnamed: 0"])
#rename column 0 into weight
df_edges = df_edges.rename(columns={'0': "weight"})
geo_dict = pd.read_csv(f"data/geo_dict_{TOPIC_NAME}.csv")
geo_dict.columns = ["institution_id", 'name', 'country', 'latitude', 'longitude']
#use geo_dict to add insitution names and countries to df_edges
df_edges = df_edges.merge(geo_dict[["institution_id", "name", "country"]], left_on="institution1", right_on="institution_id", how="left").drop(columns=["institution_id"]).rename(columns={"name": "institution1_name", "country": "institution1_country"})
df_edges = df_edges.merge(geo_dict[["institution_id", "name", "country"]], left_on="institution2", right_on="institution_id", how="left").drop(columns=["institution_id"]).rename(columns={"name": "institution2_name", "country": "institution2_country"})
#open file to write results
with open(f"data/results/reciprocal_edges_{TOPIC_NAME}.txt", "w") as f:
    for year in range(2005, 2026):
        print(f"Year: {year}")
        f.write(f"Year: {year}\n")
        df_year = df_edges[df_edges["year"] == str(year)]
        #print institution1 name (country) <-> institution2 name (country) : weight
        for index, row in df_year.iterrows():
            print(f"{row['institution1_name']} ({row['institution1_country']}) <-> {row['institution2_name']} ({row['institution2_country']}): {int(row['weight'])}")
            f.write(f"{row['institution1_name']} ({row['institution1_country']}) <-> {row['institution2_name']} ({row['institution2_country']}): {int(row['weight'])}\n")
# Out:
# Year: 2005
# Massey University (NZ) <-> Fonterra (New Zealand) (NZ): 27
# Le Mans Université (FR) <-> Centre National de la Recherche Scientifique (FR): 22
# Norwich Research Park (GB) <-> Quadram Institute (GB): 20
# Agricultural Research Service (US) <-> Eastern Regional Research Center (US): 20
# Wageningen University & Research (NL) <-> University of Leeds (GB): 16
# Year: 2006
# Fonterra (New Zealand) (NZ) <-> Massey University (NZ): 29
# Nederlands Instituut Voor Zuivel Oonderzoek (NL) <-> Wageningen University & Research (NL): 16
# Fundación Ciencias Exactas y Naturales (AR) <-> University of Buenos Aires (AR): 13
# Wageningen University & Research (NL) <-> North Carolina State University (US): 11
# Le Mans Université (FR) <-> Centre National de la Recherche Scientifique (FR): 11
# Year: 2007
# Centre National de la Recherche Scientifique (FR) <-> Le Mans Université (FR): 26
# Wageningen University & Research (NL) <-> Nederlands Instituut Voor Zuivel Oonderzoek (NL): 24
# Centre National de la Recherche Scientifique (FR) <-> Interface (United States) (US): 17
# Interface (United States) (US) <-> Le Mans Université (FR): 17
# Universidad de Sevilla (ES) <-> Fundación Ciencias Exactas y Naturales (AR): 12
# Year: 2008
# Centre National de la Recherche Scientifique (FR) <-> Le Mans Université (FR): 38
# Max Planck Society (DE) <-> Max Planck Institute of Colloids and Interfaces (DE): 33
# Centre National de la Recherche Scientifique (FR) <-> Interface (United States) (US): 33
# Interface (United States) (US) <-> Le Mans Université (FR): 33
# University of Massachusetts Amherst (US) <-> State Key Laboratory of Food Science and Technology (CN): 40
# University of Massachusetts Amherst (US) <-> China Agricultural University (CN): 39
# Year: 2018
# Jiangnan University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 160
# State Key Laboratory of Food Science and Technology (CN) <-> Nanchang University (CN): 75
# University of Massachusetts Amherst (US) <-> Jiangnan University (CN): 41
# University College Cork (IE) <-> Teagasc - The Irish Agriculture and Food Development Authority (IE): 36
# Centre National de la Recherche Scientifique (FR) <-> Le Mans Université (FR): 31
# Year: 2019
# Jiangnan University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 166
# State Key Laboratory of Food Science and Technology (CN) <-> Nanchang University (CN): 120
# Le Mans Université (FR) <-> Centre National de la Recherche Scientifique (FR): 49
# TiFN (NL) <-> Wageningen University & Research (NL): 40
# State Key Laboratory of Food Science and Technology (CN) <-> Huazhong Agricultural University (CN): 39
# Year: 2020
# Nanchang University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 138
# State Key Laboratory of Food Science and Technology (CN) <-> Jiangnan University (CN): 117
# Riddet Institute (NZ) <-> Massey University (NZ): 79
# Ministry of Agriculture and Rural Affairs (CN) <-> Shanghai Ocean University (CN): 49
# TiFN (NL) <-> Wageningen University & Research (NL): 38
# Year: 2021
# State Key Laboratory of Food Science and Technology (CN) <-> Jiangnan University (CN): 243
# Massey University (NZ) <-> Riddet Institute (NZ): 156
# Nanchang University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 151
# TiFN (NL) <-> Wageningen University & Research (NL): 102
# Northeast Agricultural University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 57
# Year: 2022
# Jiangnan University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 270
# State Key Laboratory of Food Science and Technology (CN) <-> Nanchang University (CN): 127
# Northeast Agricultural University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 80
# State Key Laboratory of Food Science and Technology (CN) <-> Huazhong Agricultural University (CN): 61
# TiFN (NL) <-> Wageningen University & Research (NL): 57
# Year: 2023
# State Key Laboratory of Food Science and Technology (CN) <-> Jiangnan University (CN): 304
# Nanchang University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 140
# Northeast Agricultural University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 113
# Northeast Agricultural University (CN) <-> Nanchang University (CN): 72
# Shanghai Ocean University (CN) <-> Ministry of Agriculture and Rural Affairs (CN): 65
# Year: 2024
# State Key Laboratory of Food Science and Technology (CN) <-> Jiangnan University (CN): 282
# Nanchang University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 142
# Northeast Agricultural University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 134
# Northeast Agricultural University (CN) <-> Jiangnan University (CN): 86
# Northeast Agricultural University (CN) <-> Jiangsu University (CN): 76
# Year: 2025
# State Key Laboratory of Food Science and Technology (CN) <-> Northeast Agricultural University (CN): 146
# Nanchang University (CN) <-> State Key Laboratory of Food Science and Technology (CN): 131
# State Key Laboratory of Food Science and Technology (CN) <-> Jiangnan University (CN): 128
# Northeast Agricultural University (CN) <-> Jiangnan University (CN): 84
# Riddet Institute (NZ) <-> Massey University (NZ): 82
